# %%
import pandas as pd

# %%
file = "COVID-19-ML-CSV.csv"
full_results_df1 = pd.read_csv(file)
full_results_df1
# Out:
#         case_month res_state  state_fips_code res_county  county_fips_code  \
# 0          2020-11        IN               18      POSEY           18129.0
# 1          2021-03        KY               21   WOODFORD           21239.0
# 2          2020-08        MI               26     ANTRIM           26009.0
# 3          2021-07        WA               53     ASOTIN           53003.0
# 4          2020-07        WI               55       IOWA           55049.0
# ...            ...       ...              ...        ...               ...
# 1048570    2020-11        MN               27   NICOLLET           27103.0
# 1048571    2021-08        NY               36   TOMPKINS           36109.0
# 1048572    2021-09        IL               17       COOK           17031.0
# 1048573    2020-12        CA                6  SAN MATEO            6081.0
# 1048574    2021-08        NY               36   RICHMOND           36085.0
#
#               age_group     sex     race        ethnicity  \
# 0          0 - 17 years     NaN      NaN              NaN
# 1          0 - 17 years     NaN      NaN              NaN
# 2        18 to 49 years     NaN      NaN              NaN
# 3        18 to 49 years     NaN      NaN              NaN
# 4        18 to 49 years     NaN      NaN              NaN
# ...                 ...     ...      ...              ...
# 1048570  18 to 49 years    Male    White          Missing
# 1048571  18 to 49 years    Male    White          Unknown
# 1048572  50 to 64 years  Female  Missing  Hispanic/Latino
# 1048573    0 - 17 years  Female    White  Hispanic/Latino
# 1048574  50 to 64 years  Female    White  Hispanic/Latino
#
#          case_positive_specimen_interval  case_onset_interval  process  \
# 0                                    0.0                  NaN  Missing
# 1                                    NaN                  0.0  Missing
# 2                                    NaN                  0.0  Missing
# 3                                    0.0                  0.0  Missing
# 4                                    NaN                  NaN  Missing
# ...                                  ...                  ...      ...
# 1048570                              0.0                  NaN  Missing
# 1048571                              NaN                  NaN  Missing
# 1048572                              NaN                  0.0  Missing
# 1048573                              NaN                  NaN  Missing
# 1048574                              0.0                  0.0  Missing
#
#         exposure_yn             current_status symptom_status  hosp_yn  \
# 0           Missing  Laboratory-confirmed case        Missing  Missing
# 1           Missing  Laboratory-confirmed case    Symptomatic       No
# 2               Yes  Laboratory-confirmed case    Symptomatic       No
# 3           Missing  Laboratory-confirmed case    Symptomatic      Yes
# 4           Missing  Laboratory-confirmed case        Missing  Unknown
# ...             ...                        ...            ...      ...
# 1048570     Missing  Laboratory-confirmed case        Missing  Missing
# 1048571     Missing  Laboratory-confirmed case        Missing  Missing
# 1048572     Missing  Laboratory-confirmed case        Missing      Yes
# 1048573     Missing  Laboratory-confirmed case        Unknown  Missing
# 1048574     Missing  Laboratory-confirmed case    Symptomatic  Missing
#
#           icu_yn death_yn underlying_conditions_yn
# 0        Missing       No                      NaN
# 1        Missing       No                      NaN
# 2        Missing       No                      NaN
# 3        Missing  Missing                      Yes
# 4        Missing  Unknown                      NaN
# ...          ...      ...                      ...
# 1048570  Missing       No                      NaN
# 1048571  Missing       No                      NaN
# 1048572  Missing  Missing                      NaN
# 1048573  Missing       No                      NaN
# 1048574  Missing  Missing                      Yes
#
# [1048575 rows x 19 columns]

# %%
full_results_df2 = full_results_df1.drop(['case_month'], axis=1)
full_results_df2 = full_results_df2.drop(['state_fips_code'], axis=1)
full_results_df2 = full_results_df2.drop(['res_county'], axis=1)
full_results_df2 = full_results_df2.drop(['county_fips_code'], axis=1)
full_results_df2 = full_results_df2.drop(['case_positive_specimen_interval'], axis=1)
full_results_df2 = full_results_df2.drop(['case_onset_interval'], axis=1)
full_results_df2 = full_results_df2.drop(['current_status'], axis=1)
full_results_df2
# Out:
#         case_month res_state  state_fips_code       age_group     sex  \
# 0          2020-11        IN               18    0 - 17 years     NaN
# 1          2021-03        KY               21    0 - 17 years     NaN
# 2          2020-08        MI               26  18 to 49 years     NaN
# 3          2021-07        WA               53  18 to 49 years     NaN
# 4          2020-07        WI               55  18 to 49 years     NaN
# ...            ...       ...              ...             ...     ...
# 1048570    2020-11        MN               27  18 to 49 years    Male
# 1048571    2021-08        NY               36  18 to 49 years    Male
# 1048572    2021-09        IL               17  50 to 64 years  Female
# 1048573    2020-12        CA                6    0 - 17 years  Female
# 1048574    2021-08        NY               36  50 to 64 years  Female
#
#             race        ethnicity  process exposure_yn symptom_status  \
# 0            NaN              NaN  Missing     Missing        Missing
# 1            NaN              NaN  Missing     Missing    Symptomatic
# 2            NaN              NaN  Missing         Yes    Symptomatic
# 3            NaN              NaN  Missing     Missing    Symptomatic
# 4            NaN              NaN  Missing     Missing        Missing
# ...          ...              ...      ...         ...            ...
# 1048570    White          Missing  Missing     Missing        Missing
# 1048571    White          Unknown  Missing     Missing        Missing
# 1048572  Missing  Hispanic/Latino  Missing     Missing        Missing
# 1048573    White  Hispanic/Latino  Missing     Missing        Unknown
# 1048574    White  Hispanic/Latino  Missing     Missing    Symptomatic
#
#          hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0        Missing  Missing       No                      NaN
# 1             No  Missing       No                      NaN
# 2             No  Missing       No                      NaN
# 3            Yes  Missing  Missing                      Yes
# 4        Unknown  Missing  Unknown                      NaN
# ...          ...      ...      ...                      ...
# 1048570  Missing  Missing       No                      NaN
# 1048571  Missing  Missing       No                      NaN
# 1048572      Yes  Missing  Missing                      NaN
# 1048573  Missing  Missing       No                      NaN
# 1048574  Missing  Missing  Missing                      Yes
#
# [1048575 rows x 14 columns]

# %%
full_results_df2 = full_results_df2.dropna(how='any')
full_results_df2
# Out:
#         case_month res_state  state_fips_code       age_group     sex  \
# 44         2021-01        WA               53    0 - 17 years  Female
# 53         2020-04        KS               20  18 to 49 years    Male
# 54         2020-05        NJ               34  18 to 49 years    Male
# 146        2021-01        NC               37  18 to 49 years    Male
# 200        2020-05        NC               37    0 - 17 years  Female
# ...            ...       ...              ...             ...     ...
# 1048435    2020-12        NC               37  50 to 64 years    Male
# 1048447    2021-07        AR                5  18 to 49 years  Female
# 1048466    2020-08        ID               16  18 to 49 years    Male
# 1048522    2021-01        NC               37  50 to 64 years  Female
# 1048574    2021-08        NY               36  50 to 64 years  Female
#
#             race            ethnicity              process exposure_yn  \
# 44       Missing      Hispanic/Latino              Missing     Missing
# 53       Unknown      Hispanic/Latino  Clinical evaluation         Yes
# 54       Unknown      Hispanic/Latino              Missing     Missing
# 146        White      Hispanic/Latino              Missing     Unknown
# 200        White      Hispanic/Latino              Missing     Unknown
# ...          ...                  ...                  ...         ...
# 1048435    Black  Non-Hispanic/Latino              Missing     Unknown
# 1048447    White  Non-Hispanic/Latino              Missing     Missing
# 1048466    White  Non-Hispanic/Latino              Missing         Yes
# 1048522    White  Non-Hispanic/Latino              Missing     Missing
# 1048574    White      Hispanic/Latino              Missing     Missing
#
#         symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 44         Symptomatic      Yes       No  Missing                      Yes
# 53         Symptomatic       No       No       No                      Yes
# 54         Symptomatic       No  Unknown       No                      Yes
# 146        Symptomatic       No  Unknown       No                      Yes
# 200        Symptomatic       No  Unknown       No                      Yes
# ...                ...      ...      ...      ...                      ...
# 1048435    Symptomatic       No  Unknown       No                      Yes
# 1048447    Symptomatic       No  Missing  Missing                      Yes
# 1048466    Symptomatic       No  Missing  Missing                      Yes
# 1048522    Symptomatic  Unknown  Unknown       No                      Yes
# 1048574    Symptomatic  Missing  Missing  Missing                      Yes
#
# [45218 rows x 14 columns]

# %%
results_df = full_results_df2.copy()

results_df["outcome"]=""
results_df
# Out:
# C:\Users\lkwor\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         case_month res_state  state_fips_code       age_group     sex  \
# 44         2021-01        WA               53    0 - 17 years  Female
# 53         2020-04        KS               20  18 to 49 years    Male
# 54         2020-05        NJ               34  18 to 49 years    Male
# 146        2021-01        NC               37  18 to 49 years    Male
# 200        2020-05        NC               37    0 - 17 years  Female
# ...            ...       ...              ...             ...     ...
# 1048435    2020-12        NC               37  50 to 64 years    Male
# 1048447    2021-07        AR                5  18 to 49 years  Female
# 1048466    2020-08        ID               16  18 to 49 years    Male
# 1048522    2021-01        NC               37  50 to 64 years  Female
# 1048574    2021-08        NY               36  50 to 64 years  Female
#
#             race            ethnicity              process exposure_yn  \
# 44       Missing      Hispanic/Latino              Missing     Missing
# 53       Unknown      Hispanic/Latino  Clinical evaluation         Yes
# 54       Unknown      Hispanic/Latino              Missing     Missing
# 146        White      Hispanic/Latino              Missing     Unknown
# 200        White      Hispanic/Latino              Missing     Unknown
# ...          ...                  ...                  ...         ...
# 1048435    Black  Non-Hispanic/Latino              Missing     Unknown
# 1048447    White  Non-Hispanic/Latino              Missing     Missing
# 1048466    White  Non-Hispanic/Latino              Missing         Yes
# 1048522    White  Non-Hispanic/Latino              Missing     Missing
# 1048574    White      Hispanic/Latino              Missing     Missing
#
#         symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn  \
# 44         Symptomatic      Yes       No  Missing                      Yes
# 53         Symptomatic       No       No       No                      Yes
# 54         Symptomatic       No  Unknown       No                      Yes
# 146        Symptomatic       No  Unknown       No                      Yes
# 200        Symptomatic       No  Unknown       No                      Yes
# ...                ...      ...      ...      ...                      ...
# 1048435    Symptomatic       No  Unknown       No                      Yes
# 1048447    Symptomatic       No  Missing  Missing                      Yes
# 1048466    Symptomatic       No  Missing  Missing                      Yes
# 1048522    Symptomatic  Unknown  Unknown       No                      Yes
# 1048574    Symptomatic  Missing  Missing  Missing                      Yes
#
#         outcome
# 44
# 53
# 54
# 146
# 200
# ...         ...
# 1048435
# 1048447
# 1048466
# 1048522
# 1048574
#
# [45218 rows x 15 columns]

# %%
for x in len(results_df):

    if results_df["death_yn"] == "yes":
        results_df["outcome"]="death"
    elif (results_df["hosp_yn"] != "yes") & (results_df["icu_yn"] != "yes") & (results_df["death_yn"] != "yes"):
        results_df["outcome"]="mild"
    elif (results_df["hosp_yn"] != "yes") & (results_df["icu_yn"] == "yes") & (results_df["death_yn"] != "yes"):
        results_df["outcome"]="icu"
    elif (results_df["hosp_yn"] == "yes") & (results_df["icu_yn"] != "yes") & (results_df["death_yn"] != "yes"):
        results_df["outcome"]="hosp"
    elif (results_df["hosp_yn"] == "yes") & (results_df["icu_yn"] == "yes") & (results_df["death_yn"] != "yes"):
        results_df["outcome"]="icu"
    else:
        results_df["outcome"]="mild"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-2cb2fd6ef9ea> in <module>
#       2
#       3
# ----> 4 if results_df["death_yn"] == "yes":
#       5     results_df["outcome"]="death"
#       6 elif (results_df["hosp_yn"] != "yes") & (results_df["icu_yn"] != "yes") & (results_df["death_yn"] != "yes"):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1441     def __nonzero__(self):
#    1442         raise ValueError(
# -> 1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1445         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
results_df = results_df.drop(['hosp_yn'], axis=1)
results_df = results_df.drop(['icu_yn'], axis=1)
results_df = results_df.drop(['death_yn'], axis=1)
results_df

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# Customize encoder.
results_encoded_df = results_df.copy()

state_num={"AL":1, "AK":2, "AZ":3, "AR":4, "CA":5, "CO":6, "CT":7, "DE":8, "FL":9, "GA":10, "HI":11, "ID":12, "IL":13, "IN":14,
           "IA":15, "KS":16, "KY":17, "LA":18, "ME":19, "MD":20, "MA":21, "MI":22, "MN":23, "MS":24, "MO":25, "MT":26, "NE":27,
           "NV":28, "NH":29, "NJ":30, "NM":31, "NY":32, "NC":33, "ND":34, "OH":35, "OK":36, "OR":37, "PA":38, "RI":39, "SC":40,
           "SD":41, "TN":42, "TX":43, "UT":44, "VT":45, "VA":46, "WA":47, "WV":48, "WI":49, "WY":50}
age_num={"0 - 17 years":17, "18 to 49 years":1849, "50 to 64 years":5064, "65+ years":65, "Missing":0, "NA":0}
sex_num={"Female":1, "Male":2, "Missing":0, "NA":0, "Unknown":0}
race_num={"American Indian/Alaska Native":1, "Asian":2, "Black":3, "Native Hawaiian/Other Pacific Islander":4,
      "White":5, "Multiple/Other":6, "Missing":0, "NA":0, "Unknown":0}
eth_num={"Hispanic/Latino":1, "Non-Hispanic/Latino":2, "Missing":0, "NA":0, "Unknown":0}
process_num={"Autopsy":1, "Clinical evaluation":2, "Contact tracing of case patient":3, "Laboratory reported":4,
         "Provider reported":5, "Routine physical examination":6, "Routine surveillance":7, "Multiple":8,
         "Missing":0, "Other":0, "Other detection method (specify)":0, "Unknown":0}
exposure_num={"Yes":1, "Missing":0, "Unknown":0}
symptom_num={"Asynptomatic":1, "Symptomatic":2, "Missing":0, "Unknown":0}
underlying_num={"No":0, "Yes":1,}
outcome_num={"mild":0, "hosp":1, "icu":2, "death":3}

# Encode the columns, then drop original columns

nums = ("state_num", "age_num", "sex_num", "race_num", "eth_num", "process_num", "exposure_num",
        "symptom_num", "underlying_num", "outcome_num")

columns = ("res_state", "age_group", "sex", "race", "ethnicity", "process", "exposure_yn", "symptom_status", 
           "underlying_conditions_yn", "outcome")

for num in nums:
    results_encoded_df[nums]=full_results_df2[columns].apply(lambda x: nums)

for column in columns:
    results_encoded_df = full_results_df3.drop(columns, axis=1)

results_encoded_df   

# results_encoded_df["state_num"]=full_results_df2["res_state"].apply(lambda x:"state_num")
# results_encoded_df["age_num"]=full_results_df2["age_group"].apply(lambda x:"age_num")
# results_encoded_df["sex_num"]=full_results_df2["sex"].apply(lambda x:"sex_num")
# results_encoded_df["race_num"]=full_results_df2["race"].apply(lambda x:"race_num")
# results_encoded_df["eth_num"]=full_results_df2["ethnicity"].apply(lambda x:"eth_num")
# results_encoded_df["process_num"]=full_results_df2["process"].apply(lambda x:"process_num")
# results_encoded_df["exposure_num"]=full_results_df2["exposure_yn"].apply(lambda x:"exposure_num")
# results_encoded_df["symptom_num"]=full_results_df2["symptom_status"].apply(lambda x:"symptom_num")
# results_encoded_df["underlying_num"]=full_results_df2["underlying_conditions_yn"].apply(lambda x:"underlying_num")
# results_encoded_df["outcome_num"]=full_results_df2["outcome"].apply(lambda x:"outcome_num")

# results_encoded_df = full_results_df2.drop("res_state", axis=1)
# results_encoded_df = full_results_df2.drop("age_group", axis=1)
# results_encoded_df = full_results_df2.drop("sex", axis=1)
# results_encoded_df = full_results_df2.drop("race", axis=1)
# results_encoded_df = full_results_df2.drop("ethnicity", axis=1)
# results_encoded_df = full_results_df2.drop("process", axis=1)
# results_encoded_df = full_results_df2.drop("exposure_yn", axis=1)
# results_encoded_df = full_results_df2.drop("symptom_status", axis=1)
# results_encoded_df = full_results_df2.drop("underlying_conditions_yn", axis=1)
# results_encoded_df = full_results_df2.drop("outcome", axis=1)

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
X = results_encoded_df.copy()
X = X.drop("death_yn", axis=1)
X

# %%
y = results_encoded_df["death_yn"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1111)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

# %%
model=tree.DecisionTreeClassifier()
model=model.fit(X_train, y_train)

# %%
predictions=model.predict(X_test)
predictions

# %%
cm = confusion_matrix(y_test, predictions)

cm_df=pd.DataFrame(cm)


# cm_df=pd.DataFrame(
#     cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])


cm_df

# %%
acc_score=accuracy_score(y_test, predictions)
acc_score

# %%
print(classification_report(y_test,predictions))
