# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cdc.gov", None)

# First 5000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("n8mc-b4w4", limit=5000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#      case_month res_state state_fips_code  res_county county_fips_code  \
# 0       2020-11        IN              18       POSEY            18129
# 1       2021-03        KY              21    WOODFORD            21239
# 2       2020-08        MI              26      ANTRIM            26009
# 3       2021-07        WA              53      ASOTIN            53003
# 4       2020-07        WI              55        IOWA            55049
# ...         ...       ...             ...         ...              ...
# 4995    2021-04        PA              42  LACKAWANNA            42069
# 4996    2021-01        FL              12     ALACHUA            12001
# 4997    2021-01        UT              49       CACHE            49005
# 4998    2021-01        OH              39    HAMILTON            39061
# 4999    2021-04        SD              46   MINNEHAHA            46099
#
# ...

# %%
results_df = results_df.drop(['case_onset_interval'], axis=1)
results_df = results_df.drop(['current_status'], axis=1)
results_df = results_df.drop(['case_positive_specimen'], axis=1)
results_df = results_df.drop(['symptom_status'], axis=1)
results_df = results_df.drop(['state_fips_code'], axis=1)
results_df = results_df.drop(['county_fips_code'], axis=1)
results_df
# Out:
#      case_month res_state  res_county       age_group     sex            race  \
# 0       2020-11        IN       POSEY    0 - 17 years      NA              NA
# 1       2021-03        KY    WOODFORD    0 - 17 years      NA              NA
# 2       2020-08        MI      ANTRIM  18 to 49 years      NA              NA
# 3       2021-07        WA      ASOTIN  18 to 49 years      NA              NA
# 4       2020-07        WI        IOWA  18 to 49 years      NA              NA
# ...         ...       ...         ...             ...     ...             ...
# 4995    2021-04        PA  LACKAWANNA  18 to 49 years    Male  Multiple/Other
# 4996    2021-01        FL     ALACHUA    0 - 17 years  Female           White
# 4997    2021-01        UT       CACHE    0 - 17 years  Female           White
# 4998    2021-01        OH    HAMILTON    0 - 17 years  Female           White
# 4999    2021-04        SD   MINNEHAHA    0 - 17 years  Female           White
#
# ...
