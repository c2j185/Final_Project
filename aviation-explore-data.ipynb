# %%
import pandas as pd
data_to_load = "AviationData.csv"
aviation_df = pd.read_csv(data_to_load, encoding="latin-1")
aviation_df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0         2.02102E+13           Accident      CEN21FA130  2021-02-16
# 1         2.02102E+13           Accident      ERA21FA130  2021-02-15
# 2         2.02102E+13           Accident      ANC21LA017  2021-02-13
# 3         2.02102E+13           Accident      CEN21LA127  2021-02-12
# 4         2.02102E+13           Accident      ERA21LA131  2021-02-10
# ...               ...                ...             ...         ...
# 85971  20041105X01764           Accident      CHI79FA064  1979-08-02
# 85972  20001218X45448           Accident      LAX96LA321  1977-06-19
# 85973  20061025X01555           Accident      NYC07LA005  1974-08-30
# 85974  20001218X45447           Accident      LAX94LA336  1962-07-19
# 85975  20001218X45444           Accident      SEA87LA080  1948-10-24
#
#                  LOCATION        Country   Latitude   Longitude Airport.Code  \
# ...

# %%
aviation_df.isnull().sum()
# Out:
# Event.Id                      0
# Investigation.Type           13
# Accident.Number               0
# Event.Date                    0
# LOCATION                     78
# Country                     507
# Latitude                  54389
# Longitude                 54398
# Airport.Code              37364
# Airport.Name              34678
# Injury.Severity             134
# Aircraft.damage            2929
# Aircraft.Category         56750
# Registration.Number        4220
# Make                         68
# Model                        99
# Amateur.Built               680
# Number.of.Engines          5577
# Engine.Type                5104
# FAR.Description           57047
# Schedule                  73797
# Purpose.of.flight          5392
# Air.carrier               81385
# Total.Fatal.Injuries      27818
# Total.Serious.Injuries    30510
# Total.Minor.Injuries      29281
# Total.Uninjured           14884
# Weather.Condition          3672
# Broad.phase.of.flight      7594
# ...

# %%
del aviation_df['Schedule']

# %%
del aviation_df['FAR.Description']

# %%
aviation_df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0         2.02102E+13           Accident      CEN21FA130  2021-02-16
# 1         2.02102E+13           Accident      ERA21FA130  2021-02-15
# 2         2.02102E+13           Accident      ANC21LA017  2021-02-13
# 3         2.02102E+13           Accident      CEN21LA127  2021-02-12
# 4         2.02102E+13           Accident      ERA21LA131  2021-02-10
# ...               ...                ...             ...         ...
# 85971  20041105X01764           Accident      CHI79FA064  1979-08-02
# 85972  20001218X45448           Accident      LAX96LA321  1977-06-19
# 85973  20061025X01555           Accident      NYC07LA005  1974-08-30
# 85974  20001218X45447           Accident      LAX94LA336  1962-07-19
# 85975  20001218X45444           Accident      SEA87LA080  1948-10-24
#
#                  LOCATION        Country   Latitude   Longitude Airport.Code  \
# ...

# %%
aviation_us_df = aviation_df[aviation_df['Country']=='United States']
aviation_us_df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0         2.02102E+13           Accident      CEN21FA130  2021-02-16
# 1         2.02102E+13           Accident      ERA21FA130  2021-02-15
# 2         2.02102E+13           Accident      ANC21LA017  2021-02-13
# 3         2.02102E+13           Accident      CEN21LA127  2021-02-12
# 4         2.02102E+13           Accident      ERA21LA131  2021-02-10
# ...               ...                ...             ...         ...
# 85971  20041105X01764           Accident      CHI79FA064  1979-08-02
# 85972  20001218X45448           Accident      LAX96LA321  1977-06-19
# 85973  20061025X01555           Accident      NYC07LA005  1974-08-30
# 85974  20001218X45447           Accident      LAX94LA336  1962-07-19
# 85975  20001218X45444           Accident      SEA87LA080  1948-10-24
#
#                  LOCATION        Country   Latitude   Longitude Airport.Code  \
# ...

# %%
n = len(pd.unique(aviation_us_df['Accident.Number']))
print("The number of unique Accident.Numbers is: ", n)
# Out:
# The number of unique Accident.Numbers is:  80131

# %%
columns = aviation_us_df.columns.values.tolist()
print(columns)
# Out:
# ['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date', 'LOCATION', 'Country', 'Latitude', 'Longitude', 'Airport.Code', 'Airport.Name', 'Injury.Severity', 'Aircraft.damage', 'Aircraft.Category', 'Registration.Number', 'Make', 'Model', 'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured', 'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status', 'Publication.Date']

# %%
aviation_us_df = aviation_us_df[aviation_us_df['Amateur.Built']=='No']
aviation_us_df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0         2.02102E+13           Accident      CEN21FA130  2021-02-16
# 1         2.02102E+13           Accident      ERA21FA130  2021-02-15
# 2         2.02102E+13           Accident      ANC21LA017  2021-02-13
# 3         2.02102E+13           Accident      CEN21LA127  2021-02-12
# 4         2.02102E+13           Accident      ERA21LA131  2021-02-10
# ...               ...                ...             ...         ...
# 85971  20041105X01764           Accident      CHI79FA064  1979-08-02
# 85972  20001218X45448           Accident      LAX96LA321  1977-06-19
# 85973  20061025X01555           Accident      NYC07LA005  1974-08-30
# 85974  20001218X45447           Accident      LAX94LA336  1962-07-19
# 85975  20001218X45444           Accident      SEA87LA080  1948-10-24
#
#                  LOCATION        Country   Latitude   Longitude Airport.Code  \
# ...
