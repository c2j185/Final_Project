# %% [markdown]
# # Tree-2Outcomes-RandUnderSamp

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
file = "COVID-19-ML-CSV.csv"
full_results_df1 = pd.read_csv(file)
full_results_df1
# Out:
#         case_month res_state  state_fips_code res_county  county_fips_code  \
# 0          2020-11        IN               18      POSEY           18129.0
# 1          2021-03        KY               21   WOODFORD           21239.0
# 2          2020-08        MI               26     ANTRIM           26009.0
# 3          2021-07        WA               53     ASOTIN           53003.0
# 4          2020-07        WI               55       IOWA           55049.0
# ...            ...       ...              ...        ...               ...
# 1048570    2020-11        MN               27   NICOLLET           27103.0
# 1048571    2021-08        NY               36   TOMPKINS           36109.0
# 1048572    2021-09        IL               17       COOK           17031.0
# 1048573    2020-12        CA                6  SAN MATEO            6081.0
# 1048574    2021-08        NY               36   RICHMOND           36085.0
#
#               age_group     sex     race        ethnicity  \
# 0          0 - 17 years     NaN      NaN              NaN
# 1          0 - 17 years     NaN      NaN              NaN
# 2        18 to 49 years     NaN      NaN              NaN
# 3        18 to 49 years     NaN      NaN              NaN
# 4        18 to 49 years     NaN      NaN              NaN
# ...                 ...     ...      ...              ...
# 1048570  18 to 49 years    Male    White          Missing
# 1048571  18 to 49 years    Male    White          Unknown
# 1048572  50 to 64 years  Female  Missing  Hispanic/Latino
# 1048573    0 - 17 years  Female    White  Hispanic/Latino
# 1048574  50 to 64 years  Female    White  Hispanic/Latino
#
#          case_positive_specimen_interval  case_onset_interval  process  \
# 0                                    0.0                  NaN  Missing
# 1                                    NaN                  0.0  Missing
# 2                                    NaN                  0.0  Missing
# 3                                    0.0                  0.0  Missing
# 4                                    NaN                  NaN  Missing
# ...                                  ...                  ...      ...
# 1048570                              0.0                  NaN  Missing
# 1048571                              NaN                  NaN  Missing
# 1048572                              NaN                  0.0  Missing
# 1048573                              NaN                  NaN  Missing
# 1048574                              0.0                  0.0  Missing
#
#         exposure_yn             current_status symptom_status  hosp_yn  \
# 0           Missing  Laboratory-confirmed case        Missing  Missing
# 1           Missing  Laboratory-confirmed case    Symptomatic       No
# 2               Yes  Laboratory-confirmed case    Symptomatic       No
# 3           Missing  Laboratory-confirmed case    Symptomatic      Yes
# 4           Missing  Laboratory-confirmed case        Missing  Unknown
# ...             ...                        ...            ...      ...
# 1048570     Missing  Laboratory-confirmed case        Missing  Missing
# 1048571     Missing  Laboratory-confirmed case        Missing  Missing
# 1048572     Missing  Laboratory-confirmed case        Missing      Yes
# 1048573     Missing  Laboratory-confirmed case        Unknown  Missing
# 1048574     Missing  Laboratory-confirmed case    Symptomatic  Missing
#
#           icu_yn death_yn underlying_conditions_yn
# 0        Missing       No                      NaN
# 1        Missing       No                      NaN
# 2        Missing       No                      NaN
# 3        Missing  Missing                      Yes
# 4        Missing  Unknown                      NaN
# ...          ...      ...                      ...
# 1048570  Missing       No                      NaN
# 1048571  Missing       No                      NaN
# 1048572  Missing  Missing                      NaN
# 1048573  Missing       No                      NaN
# 1048574  Missing  Missing                      Yes
#
# [1048575 rows x 19 columns]

# %%
full_results_df2 = full_results_df1.drop(['case_month'], axis=1)
full_results_df2 = full_results_df2.drop(['state_fips_code'], axis=1)
full_results_df2 = full_results_df2.drop(['res_county'], axis=1)
full_results_df2 = full_results_df2.drop(['county_fips_code'], axis=1)
full_results_df2 = full_results_df2.drop(['case_positive_specimen_interval'], axis=1)
full_results_df2 = full_results_df2.drop(['case_onset_interval'], axis=1)
full_results_df2 = full_results_df2.drop(['current_status'], axis=1)
full_results_df2
# Out:
#         res_state       age_group     sex     race        ethnicity  process  \
# 0              IN    0 - 17 years     NaN      NaN              NaN  Missing
# 1              KY    0 - 17 years     NaN      NaN              NaN  Missing
# 2              MI  18 to 49 years     NaN      NaN              NaN  Missing
# 3              WA  18 to 49 years     NaN      NaN              NaN  Missing
# 4              WI  18 to 49 years     NaN      NaN              NaN  Missing
# ...           ...             ...     ...      ...              ...      ...
# 1048570        MN  18 to 49 years    Male    White          Missing  Missing
# 1048571        NY  18 to 49 years    Male    White          Unknown  Missing
# 1048572        IL  50 to 64 years  Female  Missing  Hispanic/Latino  Missing
# 1048573        CA    0 - 17 years  Female    White  Hispanic/Latino  Missing
# 1048574        NY  50 to 64 years  Female    White  Hispanic/Latino  Missing
#
#         exposure_yn symptom_status  hosp_yn   icu_yn death_yn  \
# 0           Missing        Missing  Missing  Missing       No
# 1           Missing    Symptomatic       No  Missing       No
# 2               Yes    Symptomatic       No  Missing       No
# 3           Missing    Symptomatic      Yes  Missing  Missing
# 4           Missing        Missing  Unknown  Missing  Unknown
# ...             ...            ...      ...      ...      ...
# 1048570     Missing        Missing  Missing  Missing       No
# 1048571     Missing        Missing  Missing  Missing       No
# 1048572     Missing        Missing      Yes  Missing  Missing
# 1048573     Missing        Unknown  Missing  Missing       No
# 1048574     Missing    Symptomatic  Missing  Missing  Missing
#
#         underlying_conditions_yn
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            Yes
# 4                            NaN
# ...                          ...
# 1048570                      NaN
# 1048571                      NaN
# 1048572                      NaN
# 1048573                      NaN
# 1048574                      Yes
#
# [1048575 rows x 12 columns]

# %%
full_results_df2 = full_results_df2.dropna(how='any')
full_results_df2
# Out:
#         res_state       age_group     sex     race            ethnicity  \
# 44             WA    0 - 17 years  Female  Missing      Hispanic/Latino
# 53             KS  18 to 49 years    Male  Unknown      Hispanic/Latino
# 54             NJ  18 to 49 years    Male  Unknown      Hispanic/Latino
# 146            NC  18 to 49 years    Male    White      Hispanic/Latino
# 200            NC    0 - 17 years  Female    White      Hispanic/Latino
# ...           ...             ...     ...      ...                  ...
# 1048435        NC  50 to 64 years    Male    Black  Non-Hispanic/Latino
# 1048447        AR  18 to 49 years  Female    White  Non-Hispanic/Latino
# 1048466        ID  18 to 49 years    Male    White  Non-Hispanic/Latino
# 1048522        NC  50 to 64 years  Female    White  Non-Hispanic/Latino
# 1048574        NY  50 to 64 years  Female    White      Hispanic/Latino
#
#                      process exposure_yn symptom_status  hosp_yn   icu_yn  \
# 44                   Missing     Missing    Symptomatic      Yes       No
# 53       Clinical evaluation         Yes    Symptomatic       No       No
# 54                   Missing     Missing    Symptomatic       No  Unknown
# 146                  Missing     Unknown    Symptomatic       No  Unknown
# 200                  Missing     Unknown    Symptomatic       No  Unknown
# ...                      ...         ...            ...      ...      ...
# 1048435              Missing     Unknown    Symptomatic       No  Unknown
# 1048447              Missing     Missing    Symptomatic       No  Missing
# 1048466              Missing         Yes    Symptomatic       No  Missing
# 1048522              Missing     Missing    Symptomatic  Unknown  Unknown
# 1048574              Missing     Missing    Symptomatic  Missing  Missing
#
#         death_yn underlying_conditions_yn
# 44       Missing                      Yes
# 53            No                      Yes
# 54            No                      Yes
# 146           No                      Yes
# 200           No                      Yes
# ...          ...                      ...
# 1048435       No                      Yes
# 1048447  Missing                      Yes
# 1048466  Missing                      Yes
# 1048522       No                      Yes
# 1048574  Missing                      Yes
#
# [45218 rows x 12 columns]

# %%
# Make a copy of the df with the empty column "outcome"
results_df = full_results_df2.copy()

results_df["outcome"]=""
results_df
# Out:
#         res_state       age_group     sex     race            ethnicity  \
# 44             WA    0 - 17 years  Female  Missing      Hispanic/Latino
# 53             KS  18 to 49 years    Male  Unknown      Hispanic/Latino
# 54             NJ  18 to 49 years    Male  Unknown      Hispanic/Latino
# 146            NC  18 to 49 years    Male    White      Hispanic/Latino
# 200            NC    0 - 17 years  Female    White      Hispanic/Latino
# ...           ...             ...     ...      ...                  ...
# 1048435        NC  50 to 64 years    Male    Black  Non-Hispanic/Latino
# 1048447        AR  18 to 49 years  Female    White  Non-Hispanic/Latino
# 1048466        ID  18 to 49 years    Male    White  Non-Hispanic/Latino
# 1048522        NC  50 to 64 years  Female    White  Non-Hispanic/Latino
# 1048574        NY  50 to 64 years  Female    White      Hispanic/Latino
#
#                      process exposure_yn symptom_status  hosp_yn   icu_yn  \
# 44                   Missing     Missing    Symptomatic      Yes       No
# 53       Clinical evaluation         Yes    Symptomatic       No       No
# 54                   Missing     Missing    Symptomatic       No  Unknown
# 146                  Missing     Unknown    Symptomatic       No  Unknown
# 200                  Missing     Unknown    Symptomatic       No  Unknown
# ...                      ...         ...            ...      ...      ...
# 1048435              Missing     Unknown    Symptomatic       No  Unknown
# 1048447              Missing     Missing    Symptomatic       No  Missing
# 1048466              Missing         Yes    Symptomatic       No  Missing
# 1048522              Missing     Missing    Symptomatic  Unknown  Unknown
# 1048574              Missing     Missing    Symptomatic  Missing  Missing
#
#         death_yn underlying_conditions_yn outcome
# 44       Missing                      Yes
# 53            No                      Yes
# 54            No                      Yes
# 146           No                      Yes
# 200           No                      Yes
# ...          ...                      ...     ...
# 1048435       No                      Yes
# 1048447  Missing                      Yes
# 1048466  Missing                      Yes
# 1048522       No                      Yes
# 1048574  Missing                      Yes
#
# [45218 rows x 13 columns]

# %%
# Populate "outcome" column
for idx, row in results_df.iterrows():
    if row['death_yn'] == "Yes":
        row['outcome'] = "severe"
 
    elif row['hosp_yn'] != "Yes" and row['icu_yn'] != "Yes" and row['death_yn'] != "Yes":
        row['outcome'] = "mild"
           
    elif row['hosp_yn'] != "Yes" and row['icu_yn'] == "Yes" and row['death_yn'] != "Yes":
        row['outcome'] = "severe"

        # change this outcome to be severe or mild depending which class you want "hosp" to land in.
    elif row['hosp_yn'] == "Yes" and row['icu_yn'] != "Yes" and row['death_yn'] != "Yes":
        row['outcome'] = "severe"

    elif row['hosp_yn'] == "Yes" and row['icu_yn'] == "Yes" and row['death_yn'] != "Yes":
        row['outcome'] = "mild"
    
    else:
        row['outcome'] = "mild"


# Print the contents and counts of the "outcome" column
outcome_counts = results_df.outcome.value_counts()
print(outcome_counts)
# Out:
# mild      42096
# severe     3122
# Name: outcome, dtype: int64

# %%
results_df = results_df.drop(['hosp_yn'], axis=1)
results_df = results_df.drop(['icu_yn'], axis=1)
results_df = results_df.drop(['death_yn'], axis=1)
results_df
# Out:
#         res_state       age_group     sex     race            ethnicity  \
# 44             WA    0 - 17 years  Female  Missing      Hispanic/Latino
# 53             KS  18 to 49 years    Male  Unknown      Hispanic/Latino
# 54             NJ  18 to 49 years    Male  Unknown      Hispanic/Latino
# 146            NC  18 to 49 years    Male    White      Hispanic/Latino
# 200            NC    0 - 17 years  Female    White      Hispanic/Latino
# ...           ...             ...     ...      ...                  ...
# 1048435        NC  50 to 64 years    Male    Black  Non-Hispanic/Latino
# 1048447        AR  18 to 49 years  Female    White  Non-Hispanic/Latino
# 1048466        ID  18 to 49 years    Male    White  Non-Hispanic/Latino
# 1048522        NC  50 to 64 years  Female    White  Non-Hispanic/Latino
# 1048574        NY  50 to 64 years  Female    White      Hispanic/Latino
#
#                      process exposure_yn symptom_status  \
# 44                   Missing     Missing    Symptomatic
# 53       Clinical evaluation         Yes    Symptomatic
# 54                   Missing     Missing    Symptomatic
# 146                  Missing     Unknown    Symptomatic
# 200                  Missing     Unknown    Symptomatic
# ...                      ...         ...            ...
# 1048435              Missing     Unknown    Symptomatic
# 1048447              Missing     Missing    Symptomatic
# 1048466              Missing         Yes    Symptomatic
# 1048522              Missing     Missing    Symptomatic
# 1048574              Missing     Missing    Symptomatic
#
#         underlying_conditions_yn outcome
# 44                           Yes  severe
# 53                           Yes    mild
# 54                           Yes    mild
# 146                          Yes    mild
# 200                          Yes    mild
# ...                          ...     ...
# 1048435                      Yes    mild
# 1048447                      Yes    mild
# 1048466                      Yes    mild
# 1048522                      Yes    mild
# 1048574                      Yes    mild
#
# [45218 rows x 10 columns]

# %%
# Bar graph of outcome
import numpy as np
import matplotlib.pyplot as plt

# creating the dataset
mild = results_df['outcome']=='mild'
mild = results_df[results_df['outcome']=='mild']
mild = mild['outcome'].count()

severe = results_df['outcome']=='severe'
severe = results_df[results_df['outcome']=='severe']
severe = severe['outcome'].count()

outcome = {"Mild": mild, "Severe": severe}
category = list(outcome.keys())
count = list(outcome.values())
print(category)
print(count)
# Out:
# ['Mild', 'Severe']
# [42096, 3122]

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(category, count, color = 'maroon')
 
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Balance of Classes")
plt.show()

# %%
le=LabelEncoder()

# Customize encoder.
results_encoded_df = results_df.copy()
columns = ("res_state", "age_group", "sex", "race", "ethnicity", "process", "exposure_yn", "symptom_status", 
           "underlying_conditions_yn", "outcome")
for column in columns:
    results_encoded_df[column] = le.fit_transform(results_df[column])

outcome_encode = results_df[['outcome']].copy()
outcome_encode['outcome_encode'] = le.fit_transform(results_df['outcome'].values)
outcome_encode = outcome_encode.drop_duplicates('outcome')

#results_encoded_df
outcome_encode
# Out:
#    outcome  outcome_encode
# 44  severe               1
# 53    mild               0

# %%
X = results_encoded_df.copy()
X = X.drop("outcome", axis=1)
X
# Out:
#          res_state  age_group  sex  race  ethnicity  process  exposure_yn  \
# 44              37          0    0     3          0        3            0
# 53              11          1    1     6          0        0            2
# 54              24          1    1     6          0        3            0
# 146             21          1    1     7          0        3            1
# 200             21          0    0     7          0        3            1
# ...            ...        ...  ...   ...        ...      ...          ...
# 1048435         21          2    1     2          2        3            1
# 1048447          2          1    0     7          2        3            0
# 1048466          8          1    1     7          2        3            2
# 1048522         21          2    0     7          2        3            0
# 1048574         27          2    0     7          0        3            0
#
#          symptom_status  underlying_conditions_yn
# 44                    2                         1
# 53                    2                         1
# 54                    2                         1
# 146                   2                         1
# 200                   2                         1
# ...                 ...                       ...
# 1048435               2                         1
# 1048447               2                         1
# 1048466               2                         1
# 1048522               2                         1
# 1048574               2                         1
#
# [45218 rows x 9 columns]

# %%
y = results_encoded_df["outcome"].values
y
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1111)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (33913, 9)
# (11305, 9)
# (33913,)
# (11305,)

# %%
from collections import Counter
Counter(y_train)
# Out:
# Counter({0: 31574, 1: 2339})

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=1111)
X_resampled, y_resampled = rus.fit_resample(X_train, y_train)

# %%
Counter(y_resampled)
# Out:
# Counter({0: 2339, 1: 2339})

# %% [markdown]
# # Decision Tree Model

# %%
# Decision Tree Model
model=tree.DecisionTreeClassifier()
model=model.fit(X_resampled, y_resampled)

predictions=model.predict(X_test)

cm = confusion_matrix(y_test, predictions)
cm_df=pd.DataFrame(cm)
cm_df=pd.DataFrame(
    cm, index=["Actual Mild", "Actual Severe"],
    columns=["Predicted Mild", "Predicted Severe"])
cm_df
# Out:
#                Predicted Mild  Predicted Severe
# Actual Mild              7549              2973
# Actual Severe             281               502

# %%
from sklearn.metrics import balanced_accuracy_score
bal_acc_score=accuracy_score(y_test, predictions)
bal_acc_score
# Out:
# 0.7121627598407784

# %%
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test,predictions))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.96      0.72      0.64      0.82      0.68      0.46     10522
#           1       0.14      0.64      0.72      0.24      0.68      0.46       783
#
# avg / total       0.91      0.71      0.65      0.78      0.68      0.46     11305
